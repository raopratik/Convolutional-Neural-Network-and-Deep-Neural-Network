# %%
import gensim
from gensim.test.utils import datapath, get_tmpfile
from gensim.models import KeyedVectors

glove_file = datapath('/home/pratik/Downloads/glove.twitter.27B.25d.txt')
tmp_file = get_tmpfile("glove_vectors_25d.txt")

# default way (through CLI): python -m gensim.scripts.glove2word2vec --input <glove_file> --output <w2v_file>
from gensim.scripts.glove2word2vec import glove2word2vec
glove2word2vec(glove_file, tmp_file)

word_vectors = KeyedVectors.load_word2vec_format(tmp_file)

# %% [markdown]
# # HI NISHI

# %%
print('muaaaaaaaaaaaaaaaaaaah')
# Out:
# muaaaaaaaaaaaaaaaaaaah

# %%
word_vocab = word_vectors.wv.index2word
# Out:
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.

# %%
word_vectors = word_vectors.wv.vectors
# Out:
# /home/pratik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.

# %%
import pickle
file_handler = open('glove_word_vectors_25d', 'wb')
pickle.dump(word_vectors, file_handler)
file_handler = open('glove_word_list_25d', 'wb')
pickle.dump(word_vocab, file_handler)

# %%
file_handler = open('glove_word_vectors_25d', 'rb')
wordVectors = pickle.load(file_handler)
file_handler = open('glove_word_list_25d', 'rb')
wordsList = pickle.load(file_handler)

# %%
wordVectors.shape
# Out:
# (1193514, 25)

# %% [raw]
# wordsList

# %%
wordsList
# Out:
# ['<user>',
#  '.',
#  ':',
#  'rt',
#  ',',
#  '<repeat>',
#  '<hashtag>',
#  '<number>',
#  '<url>',
#  '!',
#  'i',
#  'a',
#  '"',
#  'the',
#  '?',
#  'you',
#  'to',
#  '(',
#  '<allcaps>',
#  '<elong>',
#  ')',
#  'me',
#  'de',
#  '<smile>',
#  '！',
#  'que',
#  'and',
#  '。',
#  '-',
#  'my',
#  'no',
#  '、',
#  'is',
#  'it',
#  '…',
#  'in',
#  'n',
#  'for',
#  '/',
#  'of',
#  'la',
#  "'s",
#  '*',
#  'do',
#  "n't",
#  'that',
#  'on',
#  'y',
#  "'",
#  'e',
#  'o',
#  'u',
#  'en',
#  'this',
#  'el',
#  'so',
#  'be',
#  "'m",
#  'with',
#  'just',
#  '>',
#  'your',
#  '^',
#  'like',
#  'have',
#  'te',
#  'at',
#  '？',
#  'love',
#  'se',
#  'are',
#  '<',
#  'm',
#  'r',
#  'if',
#  'all',
#  'b',
#  '・',
#  'not',
#  'but',
#  'we',
#  'es',
#  'ya',
#  '&',
#  'follow',
#  'up',
#  'what',
#  'get',
#  'lol',
#  'un',
#  '♥',
#  'lo',
#  'when',
#  'was',
#  '“',
#  '”',
#  'one',
#  'por',
#  'si',
#  'out',
#  '_',
#  'mi',
#  'can',
#  '<sadface>',
#  'من',
# ...
